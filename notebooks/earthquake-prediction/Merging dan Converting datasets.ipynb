# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/My Drive/Colab Notebooks/earthquake/1900-2019/1900-1965.csv'

# %%
df = pd.read_csv(path)
df.head()
# Out:
#    Unnamed: 0                      time  ...  locationSource  magSource
# 0           0  1900-02-16T22:10:00.000Z  ...           ushis      ushis
# 1           0  1900-04-09T14:00:00.000Z  ...           ushis        bar
# 2           0  1900-04-30T22:41:14.000Z  ...           ushis       cdmg
# 3           0  1900-07-29T06:59:00.000Z  ...          iscgem     iscgem
# 4           0  1900-08-01T07:45:00.000Z  ...           ushis      ushis
#
# [5 rows x 23 columns]

# %%
path1 = '/content/drive/My Drive/Colab Notebooks/earthquake/1900-2019/1966-1975.csv'

# %%
df1 = pd.read_csv(path1)
df1.head()
# Out:
#    Unnamed: 0                      time  ...  locationSource  magSource
# 0           0  1966-01-01T06:02:05.820Z  ...              hv         hv
# 1           1  1966-01-01T06:24:06.480Z  ...              hv         hv
# 2           2  1966-01-01T06:28:02.160Z  ...              hv         hv
# 3           3  1966-01-01T13:23:39.000Z  ...           ushis        hrn
# 4           4  1966-01-01T20:37:56.730Z  ...              hv         hv
#
# [5 rows x 23 columns]

# %%
path2 = '/content/drive/My Drive/Colab Notebooks/earthquake/1900-2019/1976-1982.csv'

# %%
df2 = pd.read_csv(path2)
df2.head()
# Out:
#    Unnamed: 0                      time  ...  locationSource  magSource
# 0           0  1976-01-01T00:04:05.400Z  ...              us         us
# 1           1  1976-01-01T00:32:44.000Z  ...              us         us
# 2           2  1976-01-01T00:35:56.200Z  ...              nm         nm
# 3           3  1976-01-01T00:42:44.200Z  ...              nm         nm
# 4           4  1976-01-01T00:48:10.100Z  ...              nm         nm
#
# [5 rows x 23 columns]

# %%
path3 = '/content/drive/My Drive/Colab Notebooks/earthquake/1900-2019/1983-1987.csv'

# %%
df3 = pd.read_csv(path3)
df3.head()
# Out:
#    Unnamed: 0                      time  ...  locationSource  magSource
# 0           0  1983-01-01T00:09:15.010Z  ...              nc         nc
# 1           1  1983-01-01T00:18:50.620Z  ...              hv         hv
# 2           2  1983-01-01T00:19:37.940Z  ...              ci         ci
# 3           3  1983-01-01T00:23:03.750Z  ...              uw         uw
# 4           4  1983-01-01T00:27:00.040Z  ...              ci         ci
#
# [5 rows x 23 columns]

# %%
path4 = '/content/drive/My Drive/Colab Notebooks/earthquake/1900-2019/1988-1992.csv'

# %%
df4 = pd.read_csv(path4)
df4.head()
# Out:
#    Unnamed: 0                      time  ...  locationSource  magSource
# 0           0  1988-01-01T00:03:09.960Z  ...              us         us
# 1           1  1988-01-01T00:06:41.010Z  ...              ci         ci
# 2           2  1988-01-01T00:22:16.050Z  ...              nc         nc
# 3           3  1988-01-01T00:52:16.000Z  ...              us        tri
# 4           4  1988-01-01T00:57:33.610Z  ...              us         us
#
# [5 rows x 23 columns]

# %%
path5 = '/content/drive/My Drive/Colab Notebooks/earthquake/1900-2019/1993-2000.csv'

# %%
df5 = pd.read_csv(path5)
df5.head()
# Out:
#    Unnamed: 0                      time  ...  locationSource  magSource
# 0           0  1993-01-01T00:03:04.490Z  ...              ci         ci
# 1           1  1993-01-01T00:35:14.660Z  ...              ci         ci
# 2           2  1993-01-01T00:44:52.060Z  ...              nc         nc
# 3           3  1993-01-01T00:59:02.010Z  ...              nc         nc
# 4           4  1993-01-01T01:05:54.630Z  ...              ci         ci
#
# [5 rows x 23 columns]

# %%
path6 = '/content/drive/My Drive/Colab Notebooks/earthquake/1900-2019/2001-2009.csv'

# %%
df6 = pd.read_csv(path6)
df6.head()
# Out:
#    Unnamed: 0                      time  ...  locationSource  magSource
# 0           0  2001-01-01T00:07:48.800Z  ...              ci         ci
# 1           1  2001-01-01T00:12:07.760Z  ...              nc         nc
# 2           2  2001-01-01T00:32:46.230Z  ...              us         us
# 3           3  2001-01-01T00:52:17.661Z  ...              ak         ak
# 4           4  2001-01-01T01:15:10.720Z  ...            rspr       rspr
#
# [5 rows x 23 columns]

# %%
path7 = '/content/drive/My Drive/Colab Notebooks/earthquake/1900-2019/2010-2016.csv'

# %%
df7 = pd.read_csv(path7)
df7.head()
# Out:
#    Unnamed: 0                      time  ...  locationSource  magSource
# 0           0  2010-01-01T00:10:43.792Z  ...              ak         ak
# 1           1  2010-01-01T00:16:49.190Z  ...              uw         uw
# 2           2  2010-01-01T00:16:54.480Z  ...              ci         ci
# 3           3  2010-01-01T00:29:29.585Z  ...              ak         ak
# 4           4  2010-01-01T00:30:16.720Z  ...              ci         ci
#
# [5 rows x 23 columns]

# %%
path8 = '/content/drive/My Drive/Colab Notebooks/earthquake/1900-2019/2017-2019.csv'

# %%
df8 = pd.read_csv(path8)
df8.head()
# Out:
#    Unnamed: 0                      time  ...  locationSource  magSource
# 0           0  2017-01-01T00:04:06.480Z  ...              ci         ci
# 1           1  2017-01-01T00:04:20.704Z  ...              nn         nn
# 2           2  2017-01-01T00:04:56.020Z  ...              ci         ci
# 3           3  2017-01-01T00:05:09.370Z  ...              ci         ci
# 4           4  2017-01-01T00:06:00.340Z  ...              ci         ci
#
# [5 rows x 23 columns]

# %%
print(f'before: {len(df)}')
df = df.append(df1)
print(f'after: {len(df)}')
# Out:
# before: 27273
# after: 2250456

# %%
print(f'before: {len(df)}')
df = df.append(df2)
print(f'after: {len(df)}')
# Out:
# before: 2250456
# after: 4834483

# %%
print(f'before: {len(df)}')
df = df.append(df3)
print(f'after: {len(df)}')
# Out:
# before: 4834483
# after: 6632210

# %%
print(f'before: {len(df)}')
df = df.append(df4)
print(f'after: {len(df)}')
# Out:
# before: 6632210
# after: 6955438

# %%
print(f'before: {len(df)}')
df = df.append(df5)
print(f'after: {len(df)}')
# Out:
# before: 6955438
# after: 7539158

# %%
print(f'before: {len(df)}')
df = df.append(df6)
print(f'after: {len(df)}')
# Out:
# before: 7539158
# after: 8481429

# %%
print(f'before: {len(df)}')
df = df.append(df7)
print(f'after: {len(df)}')
# Out:
# before: 8481429
# after: 9340714

# %%
print(f'before: {len(df)}')
df = df.append(df8)
print(f'after: {len(df)}')
# Out:
# before: 9340714
# after: 9845219

# %%
df = df.iloc[:, 1:]
df = df.sort_values('time')
df = df.reset_index()
df.head()
# Out:
#    index                      time  ...  locationSource  magSource
# 0      0  1900-02-16T22:10:00.000Z  ...           ushis      ushis
# 1      1  1900-04-09T14:00:00.000Z  ...           ushis        bar
# 2      2  1900-04-30T22:41:14.000Z  ...           ushis       cdmg
# 3      3  1900-07-29T06:59:00.000Z  ...          iscgem     iscgem
# 4      4  1900-08-01T07:45:00.000Z  ...           ushis      ushis
#
# [5 rows x 23 columns]

# %%
df = df.iloc[:, 1:]
df.head()
# Out:
#                        time  latitude  ...  locationSource  magSource
# 0  1900-02-16T22:10:00.000Z      60.0  ...           ushis      ushis
# 1  1900-04-09T14:00:00.000Z      41.4  ...           ushis        bar
# 2  1900-04-30T22:41:14.000Z      36.9  ...           ushis       cdmg
# 3  1900-07-29T06:59:00.000Z     -10.0  ...          iscgem     iscgem
# 4  1900-08-01T07:45:00.000Z      40.0  ...           ushis      ushis
#
# [5 rows x 22 columns]

# %%
from google.colab import files

# %%
# CSV 1900-2019
#df.to_csv('1900-2019.csv')

# %%
#files.download('1900-2019.csv')

# %%
df['year'] = pd.to_datetime(df['time']).dt.year
select_from = df['year'] >= 1966
select_to = df['year'] <= 2016
df_select = df[select_from & select_to]
print(f'before: {len(df)}')
print(f'after: {len(df_select)}')
# Out:
# before: 9845219
# after: 9313441

# %%
df_select.head()
# Out:
#                            time  latitude  ...  magSource  year
# 27273  1966-01-01T06:02:05.820Z   19.0685  ...         hv  1966
# 27274  1966-01-01T06:02:05.820Z   19.0685  ...         hv  1966
# 27275  1966-01-01T06:02:05.820Z   19.0685  ...         hv  1966
# 27276  1966-01-01T06:02:05.820Z   19.0685  ...         hv  1966
# 27277  1966-01-01T06:02:05.820Z   19.0685  ...         hv  1966
#
# [5 rows x 23 columns]

# %%
df_select = df_select.iloc[:, :-1]
df_select.head()
# Out:
#                            time  latitude  ...  locationSource  magSource
# 27273  1966-01-01T06:02:05.820Z   19.0685  ...              hv         hv
# 27274  1966-01-01T06:02:05.820Z   19.0685  ...              hv         hv
# 27275  1966-01-01T06:02:05.820Z   19.0685  ...              hv         hv
# 27276  1966-01-01T06:02:05.820Z   19.0685  ...              hv         hv
# 27277  1966-01-01T06:02:05.820Z   19.0685  ...              hv         hv
#
# [5 rows x 22 columns]

# %%
# CSV 1966-2016
df_select.to_csv('1966-2016.csv')

# %%
files.download('1966-2016.csv')
